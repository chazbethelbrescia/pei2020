# %% [markdown]
# # Plots for Minimum Omega Aragonite in 1990 and 2100 (Using RCP85 Ensemble Minimum)

# %% [markdown]
# ## Annual Minimum Omega Aragonite

# %%
import xarray as xr
from matplotlib import pyplot as plt
from matplotlib import gridspec
from cartopy import crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point
import glob

# %%
# %reload_ext autoreload
# %autoreload 2
from chazbpei2020.preprocessing import *

# %% [markdown]
# ## Minimum Omega Aragonite in 1990

# %% [markdown]
# ## Surface irr0.1

# %%
rootdir = '~/chazbpei2020/data/processed/Omega_Arag'
experiment = 'omega_arag_irr_0.1_ensMin_1950_2100.nc'

path = rootdir+'/'+experiment 

# Obtain the ensemble minimum (preprocessed)
ds_ensembleMin = xr.open_dataset(path)

# Specify variables
X = ds_ensembleMin['XT_OCEAN']
Y = ds_ensembleMin['YT_OCEAN']
Z = annual_min(ds_ensembleMin, 'OMEGA_ARAG_IRR', 1990)

# call contour_default function specifying variables
fig = contour_default(X, Y, Z, 10, 5)

ax = fig.get_axes()[0]
ax.set_title('Minimum Omega Aragonite in 1990 at Surface irr0.1', fontsize=20)

clevs=[0,1,2,3,4]
im = ax.contourf(X,Y,Z, levels=clevs)
cbar = plt.colorbar(im, ax=ax, orientation='horizontal', fraction=0.05, pad=0.05)
cbar.set_label('Omega Aragonite',fontsize=12)
# Out:
# /home/aos/chazb/miniconda3/envs/chazbpei2020/lib/python3.8/site-packages/xarray/core/nputils.py:215: RuntimeWarning: All-NaN slice encountered
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)

# %% [markdown]
# ## Surface k01

# %%
rootdir = '~/chazbpei2020/data/processed/Omega_Arag'
experiment = 'omega_arag_k01_ensMin_1950_2100.nc'

path = rootdir+'/'+experiment 

# Obtain the ensemble minimum (preprocessed)
ds_ensembleMin = xr.open_dataset(path)

# Specify variables
X = ds_ensembleMin['XT_OCEAN']
Y = ds_ensembleMin['YT_OCEAN']
Z = annual_min(ds_ensembleMin, 'OMEGA_ARAG', 1990)

# call contour_default function specifying variables
fig = contour_default(X, Y, Z, 10, 5)

ax = fig.get_axes()[0]
ax.set_title('Minimum Omega Aragonite in 1990 at Surface k01', fontsize=20)

clevs=[0,1,2,3,4]
im = ax.contourf(X,Y,Z, levels=clevs)
cbar = plt.colorbar(im, ax=ax, orientation='horizontal', fraction=0.05, pad=0.05)
cbar.set_label('Omega Aragonite',fontsize=12)

# %% [markdown]
# ## Surface k10

# %%
rootdir = '~/chazbpei2020/data/processed/Omega_Arag'
experiment = 'omega_arag_k10_ensMin_1950_2100.nc'

path = rootdir+'/'+experiment 

# Obtain the ensemble minimum (preprocessed)
ds_ensembleMin = xr.open_dataset(path)

# Specify variables
X = ds_ensembleMin['XT_OCEAN']
Y = ds_ensembleMin['YT_OCEAN']
Z = annual_min(ds_ensembleMin, 'OMEGA_ARAG', 1990)

# call contour_default function specifying variables
fig = contour_default(X, Y, Z, 10, 5)

ax = fig.get_axes()[0]
ax.set_title('Minimum Omega Aragonite in 1990 at Surface k10', fontsize=20)

clevs=[0,1,2,3,4]
im = ax.contourf(X,Y,Z, levels=clevs)
cbar = plt.colorbar(im, ax=ax, orientation='horizontal', fraction=0.05, pad=0.05)
cbar.set_label('Omega Aragonite',fontsize=12)

# %% [markdown]
# # --------------------------------------------------

# %% [markdown]
# ## Minimum Omega Aragonite in 2100

# %% [markdown]
# ## Surface irr0.1

# %%
rootdir = '~/chazbpei2020/data/processed/Omega_Arag'
experiment = 'omega_arag_irr_0.1_ensMin_1950_2100.nc'

path = rootdir+'/'+experiment 

# Obtain the ensemble minimum (preprocessed)
ds_ensembleMin = xr.open_dataset(path)

# Specify variables
X = ds_ensembleMin['XT_OCEAN']
Y = ds_ensembleMin['YT_OCEAN']
Z = annual_min(ds_ensembleAvg, 'OMEGA_ARAG_IRR', 2100)

# call contour_default function specifying variables
fig = contour_default(X, Y, Z, 10, 5)

ax = fig.get_axes()[0]
ax.set_title('Minimum Omega Aragonite in 2100 at Surface irr0.1', fontsize=20)

clevs=[0,1,2,3,4]
im = ax.contourf(X,Y,Z, levels=clevs)
cbar = plt.colorbar(im, ax=ax, orientation='horizontal', fraction=0.05, pad=0.05)
cbar.set_label('Omega Aragonite',fontsize=12)

# %% [markdown]
# ## Surface k01

# %%
rootdir = '~/chazbpei2020/data/processed/Omega_Arag'
experiment = 'omega_arag_k01_ensMin_1950_2100.nc'

path = rootdir+'/'+experiment 

# Obtain the ensemble minimum (preprocessed)
ds_ensembleMin = xr.open_dataset(path)

# Specify variables
X = ds_ensembleMin['XT_OCEAN']
Y = ds_ensembleMin['YT_OCEAN']
Z = annual_min(ds_ensembleMin, 'OMEGA_ARAG', 2100)

# call contour_default function specifying variables
fig = contour_default(X, Y, Z, 10, 5)

ax = fig.get_axes()[0]
ax.set_title('Minimum Omega Aragonite in 2100 at Surface k01', fontsize=20)

clevs=[0,1,2,3,4]
im = ax.contourf(X,Y,Z, levels=clevs)
cbar = plt.colorbar(im, ax=ax, orientation='horizontal', fraction=0.05, pad=0.05)
cbar.set_label('Omega Aragonite',fontsize=12)

# %% [markdown]
# ## Surface k10

# %%
rootdir = '~/chazbpei2020/data/processed/Omega_Arag'
experiment = 'omega_arag_k10_ensMin_1950_2100.nc'

path = rootdir+'/'+experiment 

# Obtain the ensemble minimum (preprocessed)
ds_ensembleMin = xr.open_dataset(path)

# Specify variables
X = ds_ensembleMin['XT_OCEAN']
Y = ds_ensembleMin['YT_OCEAN']
Z = annual_min(ds_ensembleMin, 'OMEGA_ARAG', 2100)

# call contour_default function specifying variables
fig = contour_default(X, Y, Z, 10, 5)

ax = fig.get_axes()[0]
ax.set_title('Minimum Omega Aragonite in 2100 at Surface k10', fontsize=20)

clevs=[0,1,2,3,4]
im = ax.contourf(X,Y,Z, levels=clevs)
cbar = plt.colorbar(im, ax=ax, orientation='horizontal', fraction=0.05, pad=0.05)
cbar.set_label('Omega Aragonite',fontsize=12)
